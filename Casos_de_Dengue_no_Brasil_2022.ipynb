# %% [markdown]
# <a href="https://colab.research.google.com/github/DevzsJhonny/Colab_notebooks/blob/main/Casos_de_Dengue_no_Brasil_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Série Histórica - Casos de Dengue notificados em 2022

# %%
##planilha consultada através do link: https://mosquito.saude.es.gov.br/planilhasegraficos

# %%
import pandas as pd

dados = pd.read_excel('/content/Planilhas casos notificados arboviroses SE 18_ 2022 (1).xlsx')
dados
# Out:
#                 MUNICÍPIO  SRS  SE 1  SE 2  SE 3  SE 4  SE 5  SE 6  SE 7  \
# 0            ÁGUIA BRANCA    C     0     1     0     0     0     0     0
# 1           ALTO RIO NOVO    C     0     0     0     0     0     0     0
# 2            BAIXO GUANDU    C     0     0     1     0     2     1     0
# 3                COLATINA    C     2     2     3     2     3     1     7
# 4   GOVERNADOR LINDEMBERG    C     0     0     0     0     0     0     0
# ..                    ...  ...   ...   ...   ...   ...   ...   ...   ...
# 74     PRESIDENTE KENNEDY    S     0     0     0     1     0     0     0
# 75        RIO NOVO DO SUL    S     0     0     0     1     0     0     1
# 76    SÃO JOSE DO CALÇADO    S     0     0     0     0     0     0     0
# 77            VARGEM ALTA    S     0     0     0     0     0     0     0
# 78                  TOTAL  NaN   224   275   215   175   138   163   159
#
#     SE 8  ...  SE 46  SE 47  SE 48  SE 49  SE 50  SE 51  SE 52  TOTAL  \
# ...
