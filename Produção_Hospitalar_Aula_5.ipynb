# %% [markdown]
# <a href="https://colab.research.google.com/github/DevzsJhonny/Colab_notebooks/blob/main/Produ%C3%A7%C3%A3o_Hospitalar_Aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando Dados da Saúde - Dados de Produção Hospitalar

# %%
# Dados extraídos do DATASUS

# %%
import pandas as pd

# %%
# arquivo 1
dados = pd.read_csv('A150850189_28_143_208 (1).csv', encoding='ISO-8859-1', skiprows=3,skipfooter=12, sep=';',  thousands='.', decimal=',')
# arquivo 2
#dados = pd.read_csv('/content/A152918189_28_143_208.csv', encoding='ISO-8859-1', skiprows=3,skipfooter=12, sep=';',  thousands='.', decimal=',')
# Out:
# <ipython-input-316-aa1109becf51>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv('A150850189_28_143_208 (1).csv', encoding='ISO-8859-1', skiprows=3,skipfooter=12, sep=';',  thousands='.', decimal=',')

# %%
pd.options.display.float_format = "{:.2f}".format #notação python
# ajuda a resolver os casos onde o numero fica desse jeito: 52923230878E0

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %%
# DESAFIO 1 trazer a coluna mais recente
dados['2021/Set']
# Out:
# 0       1682801.60
# 1                -
# 2       5292323.36
# 3       1496814.75
# 4       4620263.03
# 5        626751.41
# 6        312354.68
# 7      11194657.20
# 8       9371428.06
# 9      16234603.93
# 10      6055806.12
# 11      8962429.99
# 12     35603376.46
# 13      5714532.94
# 14      1509495.66
# 15     24858284.14
# 16     60010941.33
# 17     11916897.69
# 18     43133058.07
# 19    130535317.64
# 20     32660877.10
# 21     18486461.58
# 22     25200345.68
# 23      2445267.12
# 24      7325067.61
# 25     18860370.17
# 26     13173812.37
# Name: 2021/Set, dtype: object

# %% [markdown]
# # **#                                              Uso de Gráficos**

# %%
#primeira tentiva de usar o plot para criação de grafico (matplotlib ja intalado no Colab)
dados.plot(x='Unidade da Federação', y='2008/Ago', figsize=(9,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
# dessa vez vamos fazer um grafico do tipo de Barras, mudando o tamanho que é apresentado
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
# e por fim, vamos finalizar esse grafico da melhor forma
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


axis = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) # muda o numero De: 1.75 Para: 175,000,000.00

plt.title("Valor por Unidade da Federação")
plt.show()

# %%
# DESAFIO 2: fazer o mesmo processo com o Mês mais recente - 2021/Ago
# arrumar o texto dos gráficos para facilitar a leitura

# %%
import matplotlib.ticker as ticker
import matplotlib.pyplot as py

axis = dados.plot(x="Unidade da Federação", y="2021/Ago", kind="bar", figsize=(20,10))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

py.xticks(rotation=45)
#nessa ordem, se nao o titulo aparecerá erroneamente
py.title("Dados mais recentes para a Unidade de Federação em 2021")
py.show()

# %% [markdown]
# # Aula 3

# %%
dados[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# <ipython-input-326-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
# existiam linhas como '-', esse método é para desconsiderá-las
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis[:5]
# Out:
# <ipython-input-353-287140d4edeb>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   colunas_usaveis = dados.mean().index.tolist()
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis
# Out:
#       Unidade da Federação   2007/Ago   2007/Set    2007/Out    2007/Nov  \
# 0              11 Rondônia    4209.37   16397.03   133645.19   346912.84
# 1                  12 Acre   10470.07   14001.71    86200.85   301323.68
# 2              13 Amazonas   35752.72   45570.64   416012.30  2020381.79
# 3               14 Roraima    4785.91   11858.63    43852.67   369328.51
# 4                  15 Pará  181159.29  433414.74  1893197.50  5105406.44
# 5                 16 Amapá   33672.74  104822.98   118378.28   226661.18
# 6             17 Tocantins    4113.76   76633.06   343702.61  1068685.94
# 7              21 Maranhão  385330.18 1018352.93  2277717.78  4334468.23
# 8                 22 Piauí  220788.25  353468.67  1078182.68  2406035.32
# 9                 23 Ceará  357904.65  572356.18  1865065.71  5131814.39
# 10  24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 11              25 Paraíba   97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
dados_usaveis.columns
# Out:
# Index(['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov',
#        '2007/Dez', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        ...
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai',
#        '2021/Jun', '2021/Jul', '2021/Ago', 'Total'],
#       dtype='object', length=171)

# %%
dados_usaveis['2009/Ago'].head() # traz o index 0 1 2 3 4
# Out:
# 0    3787323.26
# 1    1714707.91
# 2    9267006.58
# 3    1529696.18
# 4   27892582.69
# Name: 2009/Ago, dtype: float64

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")

# %%
dados_usaveis['2009/Ago'].head() # nao traz mais o index, unidade da fed. virou o index
# Out:
# Unidade da Federação
# 11 Rondônia    3787323.26
# 12 Acre        1714707.91
# 13 Amazonas    9267006.58
# 14 Roraima     1529696.18
# 15 Pará       27892582.69
# Name: 2009/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"] #localiza
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
# .loc busca pelo index
# [] busca pelas colunas

# %%
dados_usaveis.plot(figsize=(12,6)) ## inviavel
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.head()# Transpoe as colunas x linhas
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6)) # gráfico confuso
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2021/Mai               17659855.79   4326882.24   23973537.71   3681417.80
# 2021/Jun               14435903.47   3458187.11   22175398.40   3475205.55
# 2021/Jul               11834435.10   2302711.01   21614943.55   3320807.96
# 2021/Ago                7371334.84   1196754.85   13806958.66   2907871.07
# Total                1088059702.25 475290315.34 2061943006.93 352546288.71
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Mai               50907226.77   5672086.52   10161783.68   55324683.42
# 2021/Jun               43876590.47   5469150.38    6349488.16   51958573.27
# 2021/Jul               33718084.12   4136950.62    4610170.61   37775425.78
# 2021/Ago               20837865.89   1875241.91    2304080.49   25779674.83
# Total                4968811817.17 337181964.14 1110344733.46 4161325769.23
#
# ...

# %%
#dropar Total
dados_usaveis = dados_usaveis.drop("Total",axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.max()
# Out:
# 2007/Ago     1665349.90
# 2007/Set     4434168.64
# 2007/Out    14577395.84
# 2007/Nov    35032259.98
# 2007/Dez    76668547.41
#                ...
# 2021/Abr   504427182.45
# 2021/Mai   548112705.83
# 2021/Jun   503160959.54
# 2021/Jul   404373175.61
# 2021/Ago   301986341.98
# Length: 169, dtype: float64

# %%
dados_usaveis.T.max()
# Out:
# Unidade da Federação
# 11 Rondônia                18147121.02
# 12 Acre                     5699597.78
# 13 Amazonas                27923786.94
# 14 Roraima                  5427226.70
# 15 Pará                    52558327.29
# 16 Amapá                    5672086.52
# 17 Tocantins               10161783.68
# 21 Maranhão                55324683.42
# 22 Piauí                   32550777.47
# 23 Ceará                  102825954.51
# 24 Rio Grande do Norte     41819897.10
# 25 Paraíba                 39602463.80
# 26 Pernambuco             132095684.99
# 27 Alagoas                 30875169.00
# 28 Sergipe                 19720608.49
# 29 Bahia                  134229720.19
# 31 Minas Gerais           275151838.35
# 32 Espírito Santo          58031849.50
# 33 Rio de Janeiro         252175779.88
# 35 São Paulo             1049827695.26
# 41 Paraná                 191861617.22
# 42 Santa Catarina         101661537.37
# 43 Rio Grande do Sul      169687680.33
# ...

# %%
# DESAFIO 3 - reposicionar legenda atraves do T
# colocar titulos nos dois eixos

# %%
import matplotlib.pyplot as plt
import numpy as np

dados_usaveis.T.plot(figsize=(16,9))

# para reposicionar a legenda
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left',borderaxespad=0)

# para criar titulos aos eixos X e Y
plt.xlabel("Meses Atendimento",size=14)
plt.ylabel("Valor", size=14, rotation=40)

plt.title("Valor por unidade de Federação")
plt.show()

# %%
dados_usaveis[:5] # 5 linhas
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.columns[:7]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins'],
#       dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:7]
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
# 16 Amapá              33672.74 104822.98  118378.28  226661.18   844019.90
# 17 Tocantins           4113.76  76633.06  343702.61 1068685.94  3022200.87
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# ...

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# # **Aleatoriedade**

# %%
dados_usaveis.sample(n=7) # traz aleatoriamente
# Out:
#                       2007/Ago   2007/Set   2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 28 Sergipe            27453.63   78565.19  122952.94   775705.52  2765495.63
# 12 Acre               10470.07   14001.71   86200.85   301323.68   769612.36
# 26 Pernambuco        400640.85 1088340.42 2973553.48  6699828.82 16919031.39
# 17 Tocantins           4113.76   76633.06  343702.61  1068685.94  3022200.87
# 16 Amapá              33672.74  104822.98  118378.28   226661.18   844019.90
# 41 Paraná            554800.22 1431708.01 4630402.44 11120030.79 28790722.87
# 21 Maranhão          385330.18 1018352.93 2277717.78  4334468.23  8832514.85
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 28 Sergipe            5439985.99  4636850.76  5017838.07  5265951.03
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 26 Pernambuco        51279301.86 26222079.10 30716361.81 30589332.79
# ...

# %%
import matplotlib.ticker as ticker


dados_usaveis = dados_usaveis.sample(7).T.plot(figsize=(10,6)) # Gráfico aleatório
dados_usaveis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %%
#import pandas as pd
#import numpy as np

#if isinstance(dados_usaveis, pd.DataFrame):
#  print("dados usaveis é df")
#else:
#  print("não é df")

# %%
import numpy as np

np.random.seed(66689)
dados_usaveis = dados_usaveis.sample(n=7).head() # nao trouxe mais aleatoriamente

# %%
import numpy as np

np.random.seed(66689)
dados_usaveis.sample(n=7).T.plot(figsize=(15,6))

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 52 Goiás             179395.82 418053.58 1198730.25 2712117.54  9293914.78
# 25 Paraíba            97352.78 368130.43 1002088.64 2149873.40  5448177.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
# 33 Rio de Janeiro    469469.34 921646.57 2994664.57 7250528.08 13627123.27
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 52 Goiás              76052094.77 18149374.27 20992213.03 21049477.30
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# 27 Alagoas            16623799.85  8112220.30  9210505.56 10466691.94
# 33 Rio de Janeiro    252175779.88 44128159.73 42907909.35 45315594.87
# 29 Bahia              74456787.96 33410124.06 41329594.35 42826993.62
#
# ...

# %%
# Desafio 4 ordenar o dt para que a primeira linha tenha o valor com maior gasto, e na ultima com menor.
# adicionar uma coluna com a região de cada estado
# adicionar seu estado nessa lista de 7 estados

import numpy as np

dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)

#ordenar de forma decrescente - do maior para o menor
#dados_usaveis.sort_values("Total", ascending=False)

#dados_usaveis[:7] # 7 estados

seven_estados = dados_usaveis[:7].sort_values("Total", ascending=False)
seven_estados
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 33 Rio de Janeiro    469469.34 921646.57 2994664.57 7250528.08 13627123.27
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
# 52 Goiás             179395.82 418053.58 1198730.25 2712117.54  9293914.78
# 25 Paraíba            97352.78 368130.43 1002088.64 2149873.40  5448177.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 33 Rio de Janeiro    252175779.88 44128159.73 42907909.35 45315594.87
# 29 Bahia              74456787.96 33410124.06 41329594.35 42826993.62
# 52 Goiás              76052094.77 18149374.27 20992213.03 21049477.30
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# 27 Alagoas            16623799.85  8112220.30  9210505.56 10466691.94
#
# ...

# %%
import pandas as pd
#adicionando o meu estado (São Paulo)

seven_estados = seven_estados.append(dados_usaveis.loc['35 São Paulo']) #toda vez que executar vai adicionar!!!

seven_estados = seven_estados.sort_values("Total", ascending=False)
seven_estados
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '35 São Paulo'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
seven_estados
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 33 Rio de Janeiro    469469.34 921646.57 2994664.57 7250528.08 13627123.27
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
# 52 Goiás             179395.82 418053.58 1198730.25 2712117.54  9293914.78
# 25 Paraíba            97352.78 368130.43 1002088.64 2149873.40  5448177.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 33 Rio de Janeiro    252175779.88 44128159.73 42907909.35 45315594.87
# 29 Bahia              74456787.96 33410124.06 41329594.35 42826993.62
# 52 Goiás              76052094.77 18149374.27 20992213.03 21049477.30
# 25 Paraíba            16599004.84 10871589.62 12348758.14 12680965.13
# 27 Alagoas            16623799.85  8112220.30  9210505.56 10466691.94
#
# ...

# %%
seven_estados = seven_estados.insert(0,'Siglas', ['SP','PA','AM','TO','RO','AC','RR','AP'])

# %%
seven_estados['Siglas']

# %%
#adicionando a coluna regiao para cada estado
# Norte, Nordeste, Centro, Sul, Sudeste

regioes = {
    "SP": "Sudeste",
    "PA": "Norte",
    "AM": "Norte",
    "TO": "Norte",
    "RO": "Norte",
    "AC": "Norte",
    "RR": "Norte",
    "AP": "Norte"
}

seven_estados['Região'] = seven_estados['Siglas'].apply(lambda estado: regioes[estado])
#df["Região"] = seven_estados.apply(lambda estado: regioes[estado])

# %%
seven_estados['Região']

# %%
seven_estados = seven_estados['Região'] == 'Sudeste'
seven_estados.head(1)

# %% [markdown]
# # **Aula 4**

# %%
ordenais_total = dados_usaveis.sort_values(by="Total", ascending=False)
#ordenais_total.drop("Total", axis=1, inplace=True)
ordenais_total = ordenais_total.drop("Total", axis=1)
ordenais_total.head(5)

# %%
#adicionando outro estado (12 Acre)

#ordenais_total = ordenais_total.append(dados_usaveis.loc['12 Acre']) #toda vez que executar vai adicionar!!!

# %%
ordenais_total.head().T.plot(figsize=(10,5))

# %%
ordenais_total.head(5).T.plot(figsize=(10,5))

#desafio: adicionar seu estado, ou outro estado

# %%
# desconsiderar algumas colunas

colunas_interessadas = ordenais_total.columns[6:]
ordenais_total = ordenais_total[colunas_interessadas]

# %%
ordenais_total.head(5).T.plot(figsize=(10,5))

# %%
#desafio adicionar seu estado ou outro
# refinar - titulos
# usar o sort e pesquisar sort_index
# pesquisar casos de dengue no brasil e se existe algum padrão
# plotar somente os estados de uma região

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ordenais_total = ordenais_total / 1_000_000       # 1 M
axis =  ordenais_total.head(5).T.plot(figsize=(10,6))
#axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
axis.set_ylabel("gastos aprovado em milhões de reais", size=10)
axis.set_xlabel("Meses")
#ordenais_total.head(5).T.plot(figsize=(10,5))

#plt.ylabel("Valor",size=12, rotation=(45))
#plt.xlabel("Meses",size=12)
plt.title("Análise entre os 5 maiores Estados")
plt.show()

# %%
meses_filtrados = ordenais_total.columns[47:]

axis = ordenais_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
axis.set_ylabel("gastos aprovado em milhões de reais", size=10)
axis.set_xlabel("Meses")

# %%
def plota_gastos_por_mes(dados, figsize=(10,6)):

  axis = dados.T.plot(figsize=figsize)
  axis.set_ylabel("gastos aprovado em milhões de reais", size=10)
  axis.set_xlabel("Meses")

# %%
plota_gastos_por_mes(ordenais_total[meses_filtrados].head(3))

# %%
plota_gastos_por_mes(ordenais_total[meses_filtrados].head(3))
plt.ylim(0, 600)

# %%
plota_gastos_por_mes(ordenais_total[ordenais_total.columns[45:70]].head(3))
plt.ylim(0, 340)

# %%
plota_gastos_por_mes(ordenais_total[ordenais_total.columns[-12:]].head(3)) #12 meses
plt.ylim(0, 640)

# %%
plota_gastos_por_mes(ordenais_total[ordenais_total.columns[-84:]].head(3), figsize=(15,6))
plt.ylim(0, 640)

# %%
plota_gastos_por_mes(ordenais_total.head(5)) # grafico 1
plt.ylim(0, 640)

# %%
plota_gastos_por_mes(ordenais_total.head(5), figsize=(6,6)) # grafico 2, mesmo grafico, porem com perspectivas diferentes
plt.ylim(0, 640)

# %%
plota_gastos_por_mes(ordenais_total.head(5), figsize=(20,6)) # grafico 3, mesmo grafico, porem com perspectivas diferentes
plt.ylim(0, 640)

# %%
#Desafio padronizar os ticks verticais para espaçamento de 12 em 12 unidades(uma vez ao ano)
# escolher outras cores para saltar mais aos olhos
# colocar uma grade (grid) horizontal e vertical que nao seja intrusivo

# %%
plota_gastos_por_mes(ordenais_total.head(5), figsize=(10,6)) # grafico 3, mesmo grafico, porem com perspectivas diferentes
plt.ylim(0, 640)
plt.grid(visible=None,which='major',axis='both')

# %% [markdown]
# # **Aula 5**

# %%
mes_mais_recente = ordenais_total.columns[-1]
mes_mais_recente

# %%
gastos_do_mes_recente = ordenais_total[mes_mais_recente]
gastos_do_mes_recente

# %%
tabela_de_comparacao = gastos_do_mes_recente / gastos_do_mes_recente.loc["41 Paraná"]
tabela_de_comparacao.head(5)

# %%
tabela_de_comparacao.plot(kind='barh', figsize=(10,8))

# %%
tabela_de_comparacao = tabela_de_comparacao.sort_values(ascending=False)
tabela_de_comparacao.plot(kind='bar', figsize=(10,8))

# %%
#Desafio atualizar ultimo grafico para refletir eu estado, incluindo grid, eixos, etc
#colorir seu estado com cor diferente. colorir os outros estados de acordo com o maior gasto ou menor
# gasto por população de dois estados. Escolher dois estados, pltar a comparação desses gastos de acordo com a população deles (base IBGE)
# passar uma linha horizontal no seu estado
# escolha outro valor alem de "valor aprovado" no tabnet

# %%
gastos_do_mes_recente = ordenais_total[mes_mais_recente].plot(figsize=(10,6))

# %%
gastos_do_mes_recente = ordenais_total[mes_mais_recente].plot(figsize=(10,6), kind='pie')
#gastos_do_mes_recente.sample(frac=1).plot(kind='pie')
gastos_do_mes_recente

# %%
gastos_do_mes_recente.sample(frac=1).plot(kind='pie')

# %%
import numpy as np # 2 fixos = reprodutibilidade

np.random.seed(1)
array = np.random.rand(5)
np.random.seed(1)
array2 = np.random.rand(5)
print(array)
print(array2)

# %%
import numpy as np # trouxe numeros diferentes

np.random.seed(1)
array = np.random.rand(5)

array2 = np.random.rand(5)
print(array)
print(array2)

# %%
# adicionar uma coluna com a região de cada estado
# adicionar seu estado nessa lista de 7 estados


#dados_usaveis.insert(28,"Região", ["Sudeste", "Sul","Centro-Oeste","Norte","Nordeste"])

regioes = {
     "35 São Paulo": "Sudeste",
     "31 Minas Gerais":"Sudeste",
     "41 Paraná":"Sul",
     "43 Rio Grande do Sul":"Sul",
     "33 Rio de Janeiro":"Sudeste",
     "29 Bahia":"Nordeste",
     "26 Pernambuco":"Nordeste",
     "42 Santa Catarina":"Sul",
     "23 Ceará":"Nordeste",
     "52 Goiás":"Centro-Oeste",
     "15 Pará":"Nordeste",
     "21 Maranhão":"Nordeste",
     "32 Espírito Santo":"Sudeste",
     "24 Rio Grande do Norte":"Nordeste",
     "25 Paraíba":"Nordeste",
     "53 Distrito Federal":"Centro-Oeste",
     "50 Mato Grosso do Sul":"Centro-Oeste",
     "22 Piauí":"Nordeste",
     "27 Alagoas":"Nordeste",
     "51 Mato Grosso":"Centro-Oeste",
     "13 Amazonas":"Norte",
     "28 Sergipe":"Nordeste",
     "17 Tocantins":"Nordeste",
     "11 Rondônia":"Norte",
     "12 Acre":"Norte",
     "14 Roraima":"Norte",
     "16 Amapá	":"Norte"
}

#dados_usaveis = dados_usaveis.T

#dados_usaveis["Região"] = dados_usaveis['Unidade da Federação'].apply(lambda estado: regioes.get(estado))

# %%
Norte = ['AM', 'PA', 'RR', 'AC','RO','AP', 'TO']
Sul = ['PR', 'SC', 'RS']
CentroOeste = ['MT', 'MS', 'GO', 'DF']
Nordeste = ['BA', 'CE','MA', 'PB', 'PE', 'RN', 'SE', 'AL', 'PI']
Sudeste = ['SP', 'RJ', 'MG','ES']

# %%
dados_usaveis.insert(0,"Região", 'Nan')

# %%
#dados_usaveis = dados_usaveis.drop("Região", axis=1)

# %%
dados_usaveis.head()
